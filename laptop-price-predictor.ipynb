# %%
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file=pd.read_csv("FirstTry/laptop_data.csv")
file.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
print(file.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB
# None

# %%
file.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
file=file[['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price']]

# %%
file.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
file.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
file.duplicated().sum()
# Out:
# 29

# %%
for col in file.columns:
    print(f'detaile of {col} is: \n{file[col].unique()}')
    print("x--x--"*20)
# Out:
# detaile of Company is:
# ['Apple' 'HP' 'Acer' 'Asus' 'Dell' 'Lenovo' 'Chuwi' 'MSI' 'Microsoft'
#  'Toshiba' 'Huawei' 'Xiaomi' 'Vero' 'Razer' 'Mediacom' 'Samsung' 'Google'
#  'Fujitsu' 'LG']
# x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--
# detaile of TypeName is:
# ['Ultrabook' 'Notebook' 'Netbook' 'Gaming' '2 in 1 Convertible'
#  'Workstation']
# x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--
# detaile of Inches is:
# [13.3 15.6 15.4 14.  12.  11.6 17.3 10.1 13.5 12.5 13.  18.4 13.9 12.3
#  17.  15.  14.1 11.3]
# x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--x--
# detaile of ScreenResolution is:
# ['IPS Panel Retina Display 2560x1600' '1440x900' 'Full HD 1920x1080'
#  'IPS Panel Retina Display 2880x1800' '1366x768'
# ...

# %%
file['Ram']=file['Ram'].str.replace('GB','')
file['Weight']=file['Weight'].str.replace('kg','')
file.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
file['Ram']=file['Ram'].astype('int32')
file['Weight']=file['Weight'].astype('float64')
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 107.0+ KB

# %% [markdown]
# # EDA

# %%
def countplot(col):
    sns.countplot(x=file[col], data=file,hue=file[col],palette='Spectral')
    plt.xticks(rotation=90)
    plt.show()

def priseretatione(col):
    sns.barplot(x=file[col], y=file['Price'], data=file,hue=file[col], palette='Spectral')
    plt.xticks(rotation=90)
    plt.show()

toview = ['Company', 'TypeName', 'Ram', 'OpSys','Inches']
for col in toview:
    countplot(col)
    priseretatione(col)

# %%
file['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
file['TouchScreen'] = file['ScreenResolution'].apply(lambda element:1 if 'Touchscreen' in element else 0)

file.head(20)
# Out:
#    Company   TypeName  Inches                           ScreenResolution  \
# 0    Apple  Ultrabook    13.3         IPS Panel Retina Display 2560x1600
# 1    Apple  Ultrabook    13.3                                   1440x900
# 2       HP   Notebook    15.6                          Full HD 1920x1080
# 3    Apple  Ultrabook    15.4         IPS Panel Retina Display 2880x1800
# 4    Apple  Ultrabook    13.3         IPS Panel Retina Display 2560x1600
# 5     Acer   Notebook    15.6                                   1366x768
# 6    Apple  Ultrabook    15.4         IPS Panel Retina Display 2880x1800
# 7    Apple  Ultrabook    13.3                                   1440x900
# 8     Asus  Ultrabook    14.0                          Full HD 1920x1080
# 9     Acer  Ultrabook    14.0                IPS Panel Full HD 1920x1080
# 10      HP   Notebook    15.6                                   1366x768
# 11      HP   Notebook    15.6                          Full HD 1920x1080
# ...

# %%
countplot('TouchScreen')
priseretatione('TouchScreen')

# %%
file['IPS'] = file['ScreenResolution'].apply(lambda element:1 if 'IPS' in element else 0)
file.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
countplot('IPS')
priseretatione('IPS')

# %%
file['1st split']=(file['ScreenResolution'].str.split('x',n = 1,expand=True))[0]
file['2nd split']=(file['ScreenResolution'].str.split('x',n = 1,expand=True))[1]
file.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
file['1st split']=file['1st split'].str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
file.sample(10)
# Out:
#      Company   TypeName  Inches                     ScreenResolution  \
# 99        HP     Gaming    15.6          IPS Panel Full HD 1920x1080
# 559     Dell   Notebook    15.6                             1366x768
# 1296      HP    Netbook    11.6                             1366x768
# 1293  Lenovo   Notebook    15.6          IPS Panel Full HD 1920x1080
# 261   Lenovo   Notebook    15.6                    Full HD 1920x1080
# 329     Dell   Notebook    15.6  4K Ultra HD / Touchscreen 3840x2160
# 454     Dell   Notebook    15.6                    Full HD 1920x1080
# 403     Acer   Notebook    15.6                    Full HD 1920x1080
# 114     Dell  Ultrabook    13.3          IPS Panel Full HD 1920x1080
# 680      MSI     Gaming    15.6                    Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 99             Intel Core i7 7700HQ 2.8GHz   12  128GB SSD +  1TB HDD
# ...

# %%
file['1st split']=file['1st split'].astype('int')
file['2nd split']=file['2nd split'].astype('int')
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  1st split         1303 non-null   int32
#  14  2nd split         1303 non-null   int32
# dtypes: float64(3), int32(3), int64(2), object(7)
# ...

# %%
file['PPI'] = (((file['1st split']**2+file['2nd split']**2))**0.5/file['Inches']).astype('float')
file.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
file.drop(columns=['ScreenResolution','Inches','1st split','2nd split'],inplace=True)
file.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI
# 0  226.983005
# 1  127.677940
# ...

# %%
file['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
file['CPU_name'] = file['Cpu'].apply(lambda text:" ".join(text.split()[:3]))
file.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       CPU_name
# ...

# %%
def processortype(text):
    
    if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
        return text
    
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        
        else:
            return 'AMD Processor'
        
    
    
file['CPU_name'] = file['CPU_name'].apply(lambda text:processortype(text))
file.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       CPU_name
# ...

# %%
file.sample(10)
# Out:
#      Company     TypeName                                   Cpu  Ram  \
# 358     Dell     Notebook            Intel Core i5 7200U 2.5GHz    8
# 1179      HP     Notebook            Intel Core i3 6100U 2.3GHz    4
# 800       HP  Workstation           Intel Core i7 7700HQ 2.8GHz    8
# 849       HP    Ultrabook            Intel Core i7 6500U 2.5GHz    8
# 391     Asus       Gaming           Intel Core i7 7700HQ 2.8GHz   16
# 811      MSI       Gaming           Intel Core i7 7700HQ 2.8GHz   16
# 1275    Asus    Ultrabook              Intel Core M 6Y30 0.9GHz    8
# 692       HP  Workstation           Intel Core i7 7700HQ 2.8GHz    8
# 465     Asus     Notebook  Intel Pentium Quad Core N4200 1.1GHz    4
# 94      Asus    Ultrabook            Intel Core i7 7500U 2.7GHz    8
#
#                     Memory                         Gpu       OpSys  Weight  \
# 358                2TB HDD       Intel HD Graphics 620  Windows 10    2.36
# ...

# %%
file['CPU_name'].value_counts()
# Out:
# CPU_name
# Intel Core i7            527
# Intel Core i5            423
# Other Intel Processor    154
# Intel Core i3            136
# AMD Processor             63
# Name: count, dtype: int64

# %%
file.drop(columns=['Cpu'],inplace=True)
file.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS         PPI       CPU_name
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
file['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
file['Memory'] = file['Memory'].astype(str).replace('\.0','',regex = True)
file['Memory'] = file['Memory'].str.replace('GB','')
file['Memory'] = file['Memory'].str.replace('TB','000')
file.sample(10)
# Out:
#       Company            TypeName  Ram               Memory  \
# 632    Lenovo            Notebook    4              256 SSD
# 844        HP           Ultrabook    8              512 SSD
# 1153     Dell              Gaming    8             1000 HDD
# 994      Dell  2 in 1 Convertible    8              256 SSD
# 1200     Dell            Notebook    4              128 SSD
# 673    Lenovo            Notebook    4              128 SSD
# 1018  Toshiba            Notebook    8              256 SSD
# 232    Lenovo              Gaming   16  256 SSD +  1000 HDD
# 865        HP            Notebook    4              500 HDD
# 1053       HP            Notebook    4              256 SSD
#
#                             Gpu       OpSys  Weight     Price  TouchScreen  \
# 632      Intel UHD Graphics 620  Windows 10    1.80  44169.12            0
# 844       Intel HD Graphics 520   Windows 7    1.54  99633.60            0
# 1153  Nvidia GeForce GTX 1050Ti  Windows 10    2.62  63882.72            0
# ...

# %%
spliter = file['Memory'].str.split("+",n = 1,expand = True)

spliter
# Out:
#                       0     1
# 0               128 SSD  None
# 1     128 Flash Storage  None
# 2               256 SSD  None
# 3               512 SSD  None
# 4               256 SSD  None
# ...                 ...   ...
# 1298            128 SSD  None
# 1299            512 SSD  None
# 1300   64 Flash Storage  None
# 1301           1000 HDD  None
# 1302            500 HDD  None
#
# [1303 rows x 2 columns]

# %%
file['1st_M_s'] = spliter[0]
file['1st_M_s'] = file['1st_M_s'].str.strip()
file.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS         PPI       CPU_name  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#              1st_M_s
# 0            128 SSD
# ...

# %%
def applychanges(value):
    
    file['Layer1'+value] = file['1st_M_s'].apply(lambda x:1 if value in x else 0)
    
    
listtoapply = ['HDD','SSD','Hybrid','Flash Storage']    
for value in listtoapply:
    applychanges(value)
    
    
file.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS         PPI       CPU_name  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
# ...

# %%
file['1st_M_s'] = file['1st_M_s'].astype(str).str.replace(r'\D', '', regex=True)

file['1st_M_s'].value_counts()
# Out:
# 1st_M_s
# 256     508
# 1000    250
# 128     177
# 512     140
# 500     132
# 32       45
# 64       17
# 2000     16
# 16       10
# 180       5
# 240       1
# 8         1
# 508       1
# Name: count, dtype: int64

# %%
file['2nd_M_s'] = spliter[1]
file.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS         PPI       CPU_name  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
# ...

# %%
def applychanges1(value):
    
    file['Layer2'+value] = file['2nd_M_s'].apply(lambda x:1 if value in x else 0)
    
    
listtoapply1 = ['HDD','SSD','Hybrid','Flash Storage']
file['2nd_M_s'] = file['2nd_M_s'].fillna("0")
for value in listtoapply1:
    applychanges1(value)
    

# remove all the characters just keep the numbers

file['2nd_M_s'] = file['2nd_M_s'].str.replace(r'\D','',regex=True)
file['2nd_M_s'].value_counts()
# Out:
# 2nd_M_s
# 0       1095
# 1000     187
# 2000      15
# 256        3
# 500        2
# 512        1
# Name: count, dtype: int64

# %%
file['1st_M_s'] = file['1st_M_s'].astype('int')
file['2nd_M_s'] = file['2nd_M_s'].astype('int')
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              1303 non-null   object
#  1   TypeName             1303 non-null   object
#  2   Ram                  1303 non-null   int32
#  3   Memory               1303 non-null   object
#  4   Gpu                  1303 non-null   object
#  5   OpSys                1303 non-null   object
#  6   Weight               1303 non-null   float64
#  7   Price                1303 non-null   float64
#  8   TouchScreen          1303 non-null   int64
#  9   IPS                  1303 non-null   int64
#  10  PPI                  1303 non-null   float64
#  11  CPU_name             1303 non-null   object
#  12  1st_M_s              1303 non-null   int32
#  13  Layer1HDD            1303 non-null   int64
#  14  Layer1SSD            1303 non-null   int64
# ...

# %%
file["HDD"]=(file["1st_M_s"]*file["Layer1HDD"]+file["2nd_M_s"]*file["Layer2HDD"])
file["SSD"]=(file["1st_M_s"]*file["Layer1SSD"]+file["2nd_M_s"]*file["Layer2SSD"])
file["Hybrid"]=(file["1st_M_s"]*file["Layer1Hybrid"]+file["2nd_M_s"]*file["Layer2Hybrid"])
file["Flash_Storage"]=(file["1st_M_s"]*file["Layer1Flash Storage"]+file["2nd_M_s"]*file["Layer2Flash Storage"])


## dropping of uncessary columns

file.drop(columns=['1st_M_s', '2nd_M_s', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash Storage'],inplace=True)

# %%
file.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS         PPI       CPU_name  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#    HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
# Select only numeric columns
numeric_file = file.select_dtypes(include='number')

# Compute the correlation of 'Price' with other numeric columns
if 'Price' in numeric_file.columns:
    correlation_with_price = numeric_file.corr()['Price']
    print(correlation_with_price)
else:
    print("Column 'Price' is not in the numeric DataFrame.")
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# TouchScreen      0.191226
# IPS              0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
file['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
file['Gpu_brand'] = file['Gpu'].apply(lambda x:x.split()[0])
file['Gpu_brand'].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
file.drop(columns=['Memory','Gpu'],inplace=True)
file.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  TouchScreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI       CPU_name  HDD  SSD  Hybrid  Flash_Storage Gpu_brand
# 0  226.983005  Intel Core i5    0  128       0              0     Intel
# 1  127.677940  Intel Core i5    0    0       0            128     Intel
# 2  141.211998  Intel Core i5    0  256       0              0     Intel
# 3  220.534624  Intel Core i7    0  512       0              0       AMD
# 4  226.983005  Intel Core i5    0  256       0              0     Intel

# %%
def setcategory(text):
    
    if text=='Windows 10' or text=='Windows 7' or text=='Windows 10 S':
        return 'Windows'
    
    elif text=='Mac OS X' or text=='macOS':
        return 'Mac'
    
    else:
        return 'Other'
    
    
file['OpSys'] = file['OpSys'].apply(lambda x:setcategory(x))

file.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  TouchScreen  IPS  \
# 0   Apple  Ultrabook    8    Mac    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8    Mac    1.34   47895.5232            0    0
# 2      HP   Notebook    8  Other    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16    Mac    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8    Mac    1.37   96095.8080            0    1
#
#           PPI       CPU_name  HDD  SSD  Hybrid  Flash_Storage Gpu_brand
# 0  226.983005  Intel Core i5    0  128       0              0     Intel
# 1  127.677940  Intel Core i5    0    0       0            128     Intel
# 2  141.211998  Intel Core i5    0  256       0              0     Intel
# 3  220.534624  Intel Core i7    0  512       0              0       AMD
# 4  226.983005  Intel Core i5    0  256       0              0     Intel

# %%
file.sample(10)
# Out:
#        Company            TypeName  Ram    OpSys  Weight       Price  \
# 4        Apple           Ultrabook    8      Mac    1.37   96095.808
# 1202      Dell  2 in 1 Convertible   16  Windows    2.00   68464.800
# 654         HP            Notebook    4    Other    1.86   19441.872
# 556   Mediacom            Notebook    4  Windows    1.35   13586.400
# 941       Asus            Notebook    4  Windows    2.80   28238.400
# 469     Lenovo           Ultrabook   12  Windows    1.40   98994.240
# 474       Asus            Notebook   12  Windows    2.06   69210.720
# 800         HP         Workstation    8  Windows    3.14  110017.872
# 1241      Asus           Ultrabook    8  Windows    1.45   68198.400
# 377       Dell            Notebook    4  Windows    1.80   16463.520
#
#       TouchScreen  IPS         PPI               CPU_name   HDD  SSD  Hybrid  \
# 4               0    1  226.983005          Intel Core i5     0  256       0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn import metrics
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn import tree

# %%
test = np.log(file['Price'])
train = file.drop(['Price'],axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(train,test,test_size=0.15,random_state=2)
X_train.shape,X_test.shape
# Out:
# ((1107, 14), (196, 14))

# %%
mapper = {i:value for i,value in enumerate(X_train.columns)}
mapper
# Out:
# {0: 'Company',
#  1: 'TypeName',
#  2: 'Ram',
#  3: 'OpSys',
#  4: 'Weight',
#  5: 'TouchScreen',
#  6: 'IPS',
#  7: 'PPI',
#  8: 'CPU_name',
#  9: 'HDD',
#  10: 'SSD',
#  11: 'Hybrid',
#  12: 'Flash_Storage',
#  13: 'Gpu_brand'}

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,3,8,13])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',metrics.r2_score(y_test,y_pred))
print('MAE',metrics.mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8876177968084069
# MAE 0.15775637203742093

# %%
predicted = []
testtrain = np.array(train)
for i in range(len(testtrain)):
    predicted.append(pipe.predict([testtrain[i]]))
    
predicted
# Out:
# C:\Users\Bhavishyaaggarwal\.conda\envs\py3.10gputensor\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# C:\Users\Bhavishyaaggarwal\.conda\envs\py3.10gputensor\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# C:\Users\Bhavishyaaggarwal\.conda\envs\py3.10gputensor\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# C:\Users\Bhavishyaaggarwal\.conda\envs\py3.10gputensor\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# ...

# %%
ans = [np.exp(predicted[i][0]) for i in range(len(predicted))]

# %%
data = file.copy()
data['Predicted Price'] = np.array(ans)
data
# Out:
#      Company            TypeName  Ram    OpSys  Weight        Price  \
# 0      Apple           Ultrabook    8      Mac    1.37   71378.6832
# 1      Apple           Ultrabook    8      Mac    1.34   47895.5232
# 2         HP            Notebook    8    Other    1.86   30636.0000
# 3      Apple           Ultrabook   16      Mac    1.83  135195.3360
# 4      Apple           Ultrabook    8      Mac    1.37   96095.8080
# ...      ...                 ...  ...      ...     ...          ...
# 1298  Lenovo  2 in 1 Convertible    4  Windows    1.80   33992.6400
# 1299  Lenovo  2 in 1 Convertible   16  Windows    1.30   79866.7200
# 1300  Lenovo            Notebook    2  Windows    1.50   12201.1200
# 1301      HP            Notebook    6  Windows    2.19   40705.9200
# 1302    Asus            Notebook    4  Windows    2.20   19660.3200
#
#       TouchScreen  IPS         PPI               CPU_name   HDD  SSD  Hybrid  \
# ...

# %%
sns.distplot(data['Price'],hist=False,color='orange',label='Actual')
sns.distplot(data['Predicted Price'],hist=False,color='blue',label='Predicted')
plt.legend()
plt.show()
# Out:
# C:\Users\Bhavishyaaggarwal\AppData\Local\Temp\ipykernel_21520\2629084388.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'],hist=False,color='orange',label='Actual')
# C:\Users\Bhavishyaaggarwal\AppData\Local\Temp\ipykernel_21520\2629084388.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...
